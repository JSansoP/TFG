# %%
import json

# %%
def read_json(path):
    with open(path, 'r') as f:
        return json.load(f)

# %%
results = read_json("C:\\Users\\sanso\\Documents\\Uni\\4t\\TFG\\other_datasets\\discursoRey20230519-194110\\discursoRey.json")

# %%
results["segments"]
# Out:
# [{'id': 0,
#   'seek': 0,
#   'start': 0.0,
#   'end': 5.8,
#   'text': ' Buenas noches, me alegra mucho poder estar en vuestros hogares y seguir cumpliendo con',
#   'tokens': [50364,
#    4078,
#    11581,
#    3514,
#    279,
#    11,
#    385,
#    44491,
#    424,
#    9824,
#    8152,
#    8755,
#    465,
#    9732,
#    377,
#    2635,
#    24855,
#    8643,
#    288,
#    18584,
#    37483,
#    7304,
#    416,
#    50647],
#   'temperature': 0.0,
#   'avg_logprob': -0.1442498247674171,
#   'compression_ratio': 1.4621513944223108,
#   'no_speech_prob': 0.010535540990531445,
#   'words': [{'word': ' Buenas',
#     'start': 0.0,
#     'end': 0.52,
#     'probability': 0.5667061284184456},
#    {'word': ' noches,',
#     'start': 0.52,
#     'end': 0.92,
#     'probability': 0.9754656255245209},
#    {'word': ' me',
#     'start': 1.16,
#     'end': 1.26,
#     'probability': 0.8930634260177612},
#    {'word': ' alegra',
#     'start': 1.26,
#     'end': 1.58,
# ...
